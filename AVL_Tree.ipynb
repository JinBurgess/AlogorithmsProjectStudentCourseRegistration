# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# used in max_heap to iterate through the input which is a vector of tuples
# this index [1:3] of the tuple is how we determin priority
def compare_tuple_list (child, largest, ind_tuple):
    # determines if child has priority over what is held in the largest position which will signal a swap in the max_heap
    if int(child[ind_tuple]) > int(largest[ind_tuple]):
        return True
    
    # determines if the children are less than the parent in priority 
    elif int(child[ind_tuple]) < int(largest[ind_tuple]):
        return False
    
    # if there isn't a swap, then enter the max_heap again but look at the next varible in the list of a tuple
    # to find if a child has a priority over the parent
    if int(child[ind_tuple]) == int(largest[ind_tuple]) and ind_tuple < 3:
        ind_tuple += 1
        return(child, largest, ind_tuple)
    
    # if no cases are met than it returns False
    return False


# heapifying the array of tuples 
def max_heap(reg_list, node_ind, N, ind_tuple):

    left = 2*node_ind+1 # getting the index of the left child
    right = 2*node_ind+2 # getting the index of the right child
    largest = node_ind # we divided the array in half and are iterating backwards to 0

    # if left child is larger than parent
    if left < N and compare_tuple_list(reg_list[left], reg_list[largest], ind_tuple): 
        largest = left
    else:
          largest = node_ind

    # if right child is larger than parent
    if right < N and compare_tuple_list(reg_list[right], reg_list[largest], ind_tuple): 
        largest = right

    # swaping child and parent
    if largest != node_ind:
        reg_list[node_ind], reg_list[largest] = reg_list[largest], reg_list[node_ind]
        max_heap(reg_list, largest, N, ind_tuple)


def build_heap(reg_list, ind_tuple):
    N = len(reg_list)
    n = (N//2)-1
    for node_ind in range(n,-1,-1):
        max_heap(reg_list,node_ind, N, ind_tuple)
    return reg_list

# changes the major into numerics based on priority listed 
def num_major (major):
    if  major == 'ds':
        return 2
    elif major == 'cs' or major == 'math':
        return 1
    else:
        return 0

# changes time of registration to negative numbers 
def reg_Date(regDate):
    regDate = -abs(regDate)
    return(regDate)


# user input necessary for inserting into the max_heap
def insert_heap(reg_list):
    flag = True
    while (flag == True):
        name = input('Insert: Type Last Name: ')
        year = int(input('What year are you in (if graduate type 5): '))
        major = int(num_major(input('What is your major(ds, cs, math, or other): ')))
        regDate = int(input('registration date: '))
        flag = input('Any more entries?: ')
       
        reg_list.append(tuple(name, major, year, regDate))   
        
        # stop inputting entries 
        flag = True if flag == 'y' else False
    
    build_heap(reg_list, 1) 
    return(reg_list)

# user input necessary for removing from the max_heap
def delete_heap(reg_list):
    if len(reg_list) == 0:
        return
    else:
        flag = True
        while (flag == True):
            pop_name = input('Type Last Name: ')
            # iterating through to see if the person you want to remove is in in the list
            for i, curr in enumerate(reg_list, start=1):
                if i<=len(reg_list):
                    check_name = reg_list[i-1]
                    check_name = check_name[0]
                    
                    if pop_name == check_name:
                        reg_list.remove(curr)

            flag = input('Any more entries?: ')
            # stop inputting entries 

        flag = True if flag == 'y' else False
    build_heap(reg_list, 1) 
    return(reg_list)


reg_list = [('l', 2, 6, -1),  ('d', 0, 6, -2), ('a', 1, 4, -2), ('j', 1, 2, -1), 
            ('k', 1, 1, -5), ('m', 0, 5, -2), ('e', 0, 2, -3), ('h', 1, 4, -1), 
            ('i', 0, 4, -4), ('b', 0, 2, -4), ('c', 2, 1, -5), ('gh', 1, 5, -3), 
            ('o', 2, 6, -3), ('p', 0, 5, -1), ('qt', 0, 2, -4), ('r', 1, 5, -1), 
            ('c', 2, 1, -5), ('g', 1, 5, -3), ('oh', 2, 6, -3), ('ph', 0, 5, -1), 
            ('q', 0, 3, -2), ('r', 1, 5, -4), ('s', 2, 2, -2), ('t', 1, 2, -3),
            ('u', 0, 6, -5), ('v', 1, 3, -2), ('w', 1, 2, -1), ('x', 2, 2, -1), 
            ('y', 0, 2, -1), ('z', 2, 6, -5)]

# build_heap(reg_list, 1)
delete_heap(reg_list)
# Out:
# [('z', 2, 6, -5),
#  ('c', 2, 1, -5),
#  ('x', 2, 2, -1),
#  ('oh', 2, 6, -3),
#  ('s', 2, 2, -2),
#  ('o', 2, 6, -3),
#  ('a', 1, 4, -2),
#  ('c', 2, 1, -5),
#  ('j', 1, 2, -1),
#  ('b', 0, 2, -4),
#  ('t', 1, 2, -3),
#  ('w', 1, 2, -1),
#  ('l', 2, 6, -1),
#  ('p', 0, 5, -1),
#  ('qt', 0, 2, -4),
#  ('h', 1, 4, -1),
#  ('g', 1, 5, -3),
#  ('i', 0, 4, -4),
#  ('ph', 0, 5, -1),
#  ('q', 0, 3, -2),
#  ('d', 0, 6, -2),
#  ('k', 1, 1, -5),
#  ('u', 0, 6, -5),
#  ('v', 1, 3, -2),
#  ('gh', 1, 5, -3),
#  ('m', 0, 5, -2),
#  ('y', 0, 2, -1),
#  ('e', 0, 2, -3)]

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

def compare_tuple_list (child, largest, ind_tuple):
    # determines if child has priority over what is held in the largest position which will signal a swap in the max_heap
    if int(child[ind_tuple]) > int(largest[ind_tuple]):
        return True
    
    # determines if the children are less than the parent in priority 
    elif int(child[ind_tuple]) < int(largest[ind_tuple]):
        return False
    
    # if there isn't a swap, then enter the max_heap again but look at the next varible in the list of a tuple
    # to find if a child has a priority over the parent
    if int(child[ind_tuple]) == int(largest[ind_tuple]) and ind_tuple < 3:
        ind_tuple += 1
        return(child, largest, ind_tuple)
    
    # if no cases are met than it returns False
    return False

def max_heap(reg_list, node_ind, N, ind_tuple):

    left = 2*node_ind+1 # getting the index of the left child
    right = 2*node_ind+2 # getting the index of the right child
    largest = node_ind # we divided the array in half and are iterating backwards to 0

    # if left child is larger than parent
    if left < N and compare_tuple_list(reg_list[left], reg_list[largest], ind_tuple): 
        largest = left
    else:
          largest = node_ind

    # if right child is larger than parent
    if right < N and compare_tuple_list(reg_list[right], reg_list[largest], ind_tuple): 
        largest = right

    # swaping child and parent
    if largest != node_ind:
        reg_list[node_ind], reg_list[largest] = reg_list[largest], reg_list[node_ind]
        max_heap(reg_list, largest, N, ind_tuple)

    return(reg_list)

def build_heap(reg_list, ind_tuple):
    N = len(reg_list)
    n = (N//2)-1
    for node_ind in range(n,-1,-1):
        max_heap(reg_list,node_ind, N, ind_tuple)
    return reg_list

# sorting the max heap in descending order 
def heap_sort(input_array):
    # sorted_list of entries in descending order 
    sorted_list = [] 
    build_heap(input_array,1) # initalizing the heap so we can then sort it correctly
    for i in range(len(input_array)-1, 0, -1):
        # swapping root node with last node/child
        input_array[0], input_array[i] = input_array[i], input_array[0]
        # adding the removed highest node from the input array and adding it to the sorted_list
        sorted_list.append(input_array.pop())

        # re-heapifying the array
        build_heap(input_array,1)


    sorted_list.append(input_array[0])
    return sorted_list

reg_list = [('m', 0, 5, -2), ('d', 0, 6, -2), ('a', 1, 4, -2), ('j', 1, 2, -1), ('k', 1, 1, -5)]
head = heap_sort(reg_list)

df = pd.DataFrame(head, columns=['Name', 'Major', 'Grade', 'Registration Day'])
print(df)
# Out:
#   Name  Major  Grade  Registration Day
# 0    a      1      4                -2
# 1    j      1      2                -1
# 2    k      1      1                -5
# 3    d      0      6                -2
# 4    m      0      5                -2

# %%
def compare_tuple_list (child, largest, ind_tuple):
    # determines if child has priority over what is held in the largest position which will signal a swap in the max_heap
    if int(child[ind_tuple]) > int(largest[ind_tuple]):
        return True
    
    # determines if the children are less than the parent in priority 
    elif int(child[ind_tuple]) < int(largest[ind_tuple]):
        return False
    
    # goes to the next variable to check for priority if the current check are the same
    if ind_tuple + 1 < len(child) and ind_tuple + 1 < len(largest):
        return int(child[ind_tuple + 1]) > int(largest[ind_tuple + 1])
    return False

# %%
def compare_dict_values(child, largest, indx):
    for tuple_values in child.values():
        child_value = tuple_values[0][indx]

    for tuple_values in largest.values():
        largest_value = tuple_values[0][indx]

    if child_value > largest_value:
        return True
    
    elif child_value < largest_value:
        return False
    
    if child_value == largest_value and indx < 3:
        indx += 1
        return compare_dict_values(child, largest, indx)
    
    return False

largest = {'a': [(2, 3, -1)]}
child = {'c': [(2, 5, -2)]}
indx = 0

compare_dict_values(child, largest, indx)
# Out:
# True

# %%
def setting_child (reg_Dict, side, N):   
    list_keys = list(reg_Dict.keys())
    if side < N:
        child_key = list_keys[side] 
        child ={child_key: reg_Dict[child_key]}
        return child
    return False

def setting_parent(reg_Dict, largest, list_keys):  
    largest_key = list_keys[largest] 
    largest_ind_entry = {largest_key:reg_Dict[largest_key]}
    return largest_ind_entry

def swap(reg_Dict, largest, dict_ind):
    swap = list(reg_Dict.items())
    swap[largest], swap[dict_ind] = swap[dict_ind], swap[largest]
    reg_Dict = dict(swap)
    return reg_Dict

# %%
def max_heap(reg_Dict, dict_ind, N):

    left = 2*dict_ind+1 # getting the index of the left child
    right = 2*dict_ind+2 # getting the index of the right child
    largest = dict_ind # we divided the array in half and are iterating backwards to 0    
    indx = 0
    
    list_keys = list(reg_Dict.keys()) 
         # Get the keys of the dictionary as a list
    left_child = setting_child(reg_Dict, left, N)
    right_child = setting_child(reg_Dict,right, N)

    largest_ind_entry = setting_parent(reg_Dict, largest, list_keys)
    # dict_ind_key = list_keys[dict_ind]
    # dict_ind_entry = {dict_ind_key:reg_Dict[dict_ind_key]}

    # print(dict_ind_entry, '\n', 'larg', largest_ind_entry, '\n', 'left', left_child, '\n', 'right', right_child, '\n')
    # if left child is larger than parent
    if left < N and compare_dict_values(left_child, largest_ind_entry, indx): 
        print('left', largest_ind_entry, left_child)
        largest_ind_entry = left_child
        largest = left
        print('left', largest)
    else:
          largest = dict_ind

    # if right child is larger than parent
    if right < N and compare_dict_values(right_child,largest_ind_entry, indx): 
        print('right', largest_ind_entry, right_child)
        largest_ind_entry = right_child
        largest = right
        print('right', largest)

    # swaping child and parent
    if largest != dict_ind:
        reg_Dict = swap(reg_Dict, largest, dict_ind)
        print('after switch', reg_Dict, largest, N)
        max_heap(reg_Dict, largest, N)

def build_heap(reg_Dict):
    N = len(reg_Dict)
    n = (N//2)-1
    for dict_ind in range(n,-1,-1):
        max_heap(reg_Dict,dict_ind, N)
    return reg_Dict

reg_Dict = {'a': [(2, 3, -1)], 'b': [(0, 4, -1)], 'c': [(1, 5, -2)], 'd': [(1, 1, -3)]} # dictionary {key, values} where the values is a tuple that contains the year, major, and registration date

print(build_heap(reg_Dict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 49
#      45     return reg_Dict
#      47 reg_Dict = {'a': [(2, 3, -1)], 'b': [(0, 4, -1)], 'c': [(1, 5, -2)], 'd': [(1, 1, -3)]} # dictionary {key, values} where the values is a tuple that contains the year, major, and registration date
# ---> 49 print(build_heap(reg_Dict))
#
# Cell In[12], line 44, in build_heap(reg_Dict)
#      42 n = (N//2)-1
#      43 for dict_ind in range(n,-1,-1):
# ---> 44     max_heap(reg_Dict,dict_ind, N)
#      45 return reg_Dict
#
# Cell In[12], line 8, in max_heap(reg_Dict, dict_ind, N)
#       5 largest = dict_ind # we divided the array in half and are iterating backwards to 0
#       6 indx = 0
# ----> 8 list_keys = list(reg_Dict.keys())
#       9      # Get the keys of the dictionary as a list
#      10 left_child = setting_child(reg_Dict, left, N)
#
# TypeError: 'NoneType' object is not callable

# %%
def compare_dict_values(child, largest, indx):
    for tuple_values in child.values():
        child_value = tuple_values[0][indx]

    for tuple_values in largest.values():
        largest_value = tuple_values[0][indx]

    if child_value > largest_value:
        return True
    
    elif child_value < largest_value:
        return False
    
    if child_value == largest_value and indx < 2:
        indx += 1
        return compare_dict_values(child, largest, indx)
    
    return False


def max_depth(node):
    if node is None:
        return 0
    else:
 
        # Compute the depth of each subtree
        left_depth = max_depth(node.left)
        right_depth = max_depth(node.right)
 
        # Use the larger one
        if left_depth > right_depth:
            depth_difference = left_depth-right_depth
            print(depth_difference)
            return True
        else:
            depth_difference = right_depth- left_depth
            print(depth_difference)
            return True
 
def setting_child (reg_Dict, side, N):   
    list_keys = list(reg_Dict.keys())
    if side < N:
        child_key = list_keys[side] 
        child ={child_key: reg_Dict[child_key]}
        return child
    return None

def setting_parent(reg_Dict, largest, list_keys):  
    largest_key = list_keys[largest] 
    largest_ind_entry = {largest_key:reg_Dict[largest_key]}
    return largest_ind_entry

def swap(reg_Dict, largest, dict_ind):
    swap = list(reg_Dict.items())
    swap[largest], swap[dict_ind] = swap[dict_ind], swap[largest]
    reg_Dict = dict(swap)
    return reg_Dict

def max_heap(reg_Dict, dict_ind, N):

    left = 2*dict_ind+1 # getting the index of the left child
    right = 2*dict_ind+2 # getting the index of the right child
    largest = dict_ind # we divided the array in half and are iterating backwards to 0    
    indx = 0
    
    list_keys = list(reg_Dict.keys()) 
         # Get the keys of the dictionary as a list
    left_child = setting_child(reg_Dict, left, N)
    right_child = setting_child(reg_Dict,right, N)

    largest_ind_entry = setting_parent(reg_Dict, largest, list_keys)
   
    if left < N and compare_dict_values(left_child, largest_ind_entry, indx): 
        print('left', largest_ind_entry, left_child)
        largest_ind_entry = left_child
        largest = left
        print('left', largest)
    else:
          largest = dict_ind

    # if right child is larger than parent
    if right < N and compare_dict_values(right_child,largest_ind_entry, indx): 
        print('right', largest_ind_entry, right_child)
        largest_ind_entry = right_child
        largest = right
        print('right', largest)

# swaping child and parent
    if largest != dict_ind:
        reg_Dict = swap(reg_Dict, largest, dict_ind)
        print('after switch', reg_Dict, largest, N)
        max_heap(reg_Dict, largest, N)
    print('iter', reg_Dict, N)
    return reg_Dict

def build_heap(reg_Dict):
    N = len(reg_Dict)
    n = (N//2)-1
    for dict_ind in range(n,-1,-1):
        max_heap(reg_Dict, dict_ind, N)
        print('aiter2', reg_Dict, N)
    print('fiter2', reg_Dict, N)
    return reg_Dict

reg_Dict = {'a': [(2, 3, -1)], 'b': [(0, 4, -1)], 'c': [(1, 5, -2)], 'd': [(1, 1, -3)]} # dictionary {key, values} where the values is a tuple that contains the year, major, and registration date

print(build_heap(reg_Dict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 107
#     103     return reg_Dict
#     105 reg_Dict = {'a': [(2, 3, -1)], 'b': [(0, 4, -1)], 'c': [(1, 5, -2)], 'd': [(1, 1, -3)]} # dictionary {key, values} where the values is a tuple that contains the year, major, and registration date
# --> 107 print(build_heap(reg_Dict))
#
# Cell In[11], line 100, in build_heap(reg_Dict)
#      98 n = (N//2)-1
#      99 for dict_ind in range(n,-1,-1):
# --> 100     max_heap(reg_Dict, dict_ind, N)
#     101     print('aiter2', reg_Dict, N)
#     102 print('fiter2', reg_Dict, N)
#
# Cell In[11], line 66, in max_heap(reg_Dict, dict_ind, N)
#      63 largest = dict_ind # we divided the array in half and are iterating backwards to 0
#      64 indx = 0
# ---> 66 list_keys = list(reg_Dict.keys())
#      67      # Get the keys of the dictionary as a list
#      68 left_child = setting_child(reg_Dict, left, N)
#
# TypeError: 'NoneType' object is not callable

# %%
class Node:
    def __init__(self, node):
        self.node = node
        self.left = None
        self.right = None
        self.height = 1

class AVL_Tree:
    def __init__(self):
        self.root = None

    # determines the tree height of each subtree, helps to determine if the subtree needs to be rotated and in which direction
    def tree_height(self, node):
        if node is None:
            return 0
        left_height = self.tree_height(node.left) # getting the height of the left subtree
        right_height = self.tree_height(node.right) # getting the height of the right subtree
        return max(left_height, right_height) + 1 # return the subtree which has the largest depth (adding 1 since we start our count at 0)

    # this is used when our subtree looks like a line that has a line right children
    def left_left_rotation(self, node):
        new_parent = node.right # setting the right child as the pivot/new parent
        temp_var = new_parent.left # temparary variable that will be reattached when tree has been rotated
        new_parent.left = node # setting parent node as left child
        node.right = temp_var # since the node is going to be smaller than the temp var, it is going to be placed as right child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right)) + 1 
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right)) + 1

        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent

    # this is used when our subtree looks like a line that has a line left children
    def right_right_rotation(self, node):
        new_parent = node.left # setting the left child as the pivot/new parent
        temp_var = new_parent.right # temparary variable that will be reattached when tree has been rotated
        new_parent.right = node # setting parent node as right child
        node.left = temp_var # since the node is going to be bigger than the temp var, it is going to be placed as left child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right))+1
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right))+1
       
        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent
      
    def left_right_rotation(self,node):
        node.left = self.right_right_rotation(node.left)
        return self.left_left_rotation(node)
    
    def right_left_rotation(self,node):
        node.right = self.left_left_rotation(node.right)
        return self.right_right_rotation(node)

    # inserting node 
    def insert(self, parent_node, inserting_node):
        # case when it is empty
        if parent_node is None:
            return Node(inserting_node)

        # inserting child node
        # inserts left if it is less than the parent node
        if inserting_node < parent_node.node:
            parent_node.left = self.insert(parent_node.left, inserting_node)

        # inserts right if greater than parent node
        else:
            parent_node.right = self.insert(parent_node.right, inserting_node)

        # updating the height of the parent node given the added child
        parent_node.height = max(self.tree_height(parent_node.left), self.tree_height(parent_node.right)) + 1

        # Check for balance of each subtree of the parent and perform rotations as needed
        balance = self.tree_height(parent_node.left) - self.tree_height(parent_node.right)

        # when the left side is deeper than the right side
        if balance > 1:
            # the inserting_node would be attached to the left child side of the parent node, making the left side of the subarray deeper than
            # the right side of the tree, thus you need to rotate the entire subarray to the right to rebalance
            if inserting_node < parent_node.left.node:
                return self.right_right_rotation(parent_node)
            else:
                return self.left_right_rotation(parent_node)

        # when the right side is deeper than the left side
        if balance < -1:
            # the inserting_node would be attached to the right child side of the parent node, making the right side of the subarray deeper than
            # the left side of the tree, thus you need to rotate the entire subarray to the right to rebalance
            if inserting_node > parent_node.right.node:
                return self.left_left_rotation(parent_node)
            else:
                return self.right_left_rotation(parent_node)

        return parent_node

    def search_AVL(self, root, value_check):
        if root is None or value_check == root.node:
            return root
        if value_check < root.node:
            return self.search_AVL(root.left, value_check)
        else:
            return self.search_AVL(root.right, value_check)

if __name__ == "__main__":
    Tree = AVL_Tree()
    root = None
    root = Tree.insert(root, 5)
    root = Tree.insert(root, 3)
    root = Tree.insert(root, 2)
    root = Tree.insert(root, 4)
    root = Tree.insert(root, 7)
    root = Tree.insert(root, 6)
    root = Tree.insert(root, 8)
    root = Tree.insert(root, 1)
    
    test_BST = [5, 4, 10, 7, 11, 1]
    for val in test_BST:
        result = Tree.search_AVL(root, val)

        if result is not None:
            print(f"Value {result.node} found in the BST.")
        else:
            print(f"Value {val} not found in the BST.")
# Out:
# Value 5 found in the BST.
# Value 4 found in the BST.
# Value 10 not found in the BST.
# Value 7 found in the BST.
# Value 11 not found in the BST.
# Value 1 found in the BST.

# %%
# class Node deals with the information about the relation and information that each node contains 
class Node:
    def __init__(self, name, values):
        self.name = name # student's name
        self.values = values # information about year, registration day, and major

        # when inputing a node there is no child attached 
        self.left = None 
        self.right = None
        self.height = 1 # will be used to help determine rebalancing 

# class AVL_Tree contains information about the structure of AVL_Tree and how to maintain it
# such as the rotation, insertion, and deletion form the tree
class AVL_Tree:
    def __init__(self):
        self.root = None

    # determines the tree height of each subtree, helps to determine if the subtree needs to be rotated and in which direction
    def tree_height(self, node):
        if node is None:
            return 0
        left_height = self.tree_height(node.left) # getting the height of the left subtree
        right_height = self.tree_height(node.right) # getting the height of the right subtree
        return max(left_height, right_height) + 1 # return the subtree which has the largest depth (adding 1 since we start our count at 0)
    
    def left_left_rotation(self, node):
        new_parent = node.right # setting the right child as the pivot/new parent
        temp_var = new_parent.left # temparary variable that will be reattached when tree has been rotated
        new_parent.left = node # setting parent node as left child
        node.right = temp_var # since the node is going to be smaller than the temp var, it is going to be placed as right child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right)) + 1 
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right)) + 1

        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent
    
    def right_right_rotation(self, node):
        new_parent = node.left # setting the left child as the pivot/new parent
        temp_var = new_parent.right # temparary variable that will be reattached when tree has been rotated
        new_parent.right = node # setting parent node as right child
        node.left = temp_var # since the node is going to be bigger than the temp var, it is going to be placed as left child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right)) + 1
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right)) + 1

        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent

    def left_right_rotation(self, node):
        node.left = self.left_left_rotation(node.left)
        return self.right_right_rotation(node)

    def right_left_rotation(self, node):
        node.right = self.right_right_rotation(node.right)
        return self.left_left_rotation(node)

    def compare_dict_values(self, values, node):
        child_value = values[3]
        largest_value = node.node[0][3]  # Access values from the current node
        # if child_value == largest_value and indx < 2:
        #     indx += 1
        #     return self.compare_dict_values(values, node, indx)  # Call recursively without 'self'
        return True if child_value > largest_value else False

    # inserting a new node into the avl tree based on the factors of their major, 
    def insert(self, parent_node, name, values):
        if parent_node is None:
            return Node(name, [values])

        if self.compare_dict_values(self, values, parent_node):
            parent_node.left = self.insert(parent_node.left, name, values)
        else:
            parent_node.right = self.insert(parent_node.right, name, values)
        parent_node.height = max(self.tree_height(parent_node.left), self.tree_height(parent_node.right)) + 1
        balance = self.tree_height(parent_node.left) - self.tree_height(parent_node.right)
        if balance > 1:
            if name < parent_node.left.name:
                return self.right_right_rotation(parent_node)
            else:
                return self.left_right_rotation(parent_node)

        if balance < -1:
            if name > parent_node.right.name:
                return self.left_left_rotation(parent_node)
            else:
                return self.right_left_rotation(parent_node)

        return parent_node

    def search_AVL(self, node, value_check):
        if node is None or value_check == node.name:
            return node
        if value_check < node.name:
            return self.search_AVL(node.left, value_check)
        else:
            return self.search_AVL(node.right, value_check)
        
    def print_tree(self, node):
        if node:
            self.print_tree(node.left)
            print(f"{node.name}: {node.values}")
            self.print_tree(node.right)

class stud_registration:
    def __init__(self):
        self.grad_list = {}
        self.undgrad_list = AVL_Tree()
        self.auditor_list = {}
        self.waitlist = {}

    def audit_priority(self,reg_day): 
        level = 0 #reset the level for each function call
        level = level + (.5-(.1*(reg_day))) # level will equal 0.5 for registrations before orientation week, 0.4 for registrations on the first day, etc.
        return(level) #returns the updated dictionary
        
    def undgrad_priority(self, major, year, reg_day):     
        level = 0
        if major == 'cs' or major == 'math':
            level = level+10 # adds 10 to the level for cs or math majors,
            
        level = level + year # adds 1,2,3, or 4 to the level based on the year. 
        level = level +(.5-(.1*(reg_day))) #+0.5 for students registered before the orientation week, same as for auditors.

        return(level) #return the updated dictionary

    def register_student(self, name,major, year, reg_day):
        if int(reg_day) < 6:
            if int(year) > 4:
                self.grad_list[name] = [(major, year, reg_day)]
            elif int(year) == 0:
                priority = self.audit_priority(reg_day)
                self.auditor_list[name] = [(major, year, reg_day)]
            else:
                priority = self.undgrad_priority(major, year, reg_day)
                self.undgrad_list.root = self.undgrad_list.insert(self.undgrad_list.root, name, (major, year, reg_day, priority))
        else:
            self.waitlist[name] = [(major, year, reg_day)]


if __name__ == "__main__":
    reg_stud = stud_registration()
    list = None
    reg_stud.register_student('a', 'cs', 4, 3)
    reg_stud.register_student('b', 'math', 3, 4)
    reg_stud.register_student('c', 'cs',3, 6)
    reg_stud.register_student('d', 'cs', 4, 2)
    reg_stud.register_student('e', 'art',  0, 1)
    reg_stud.register_student('f', 'cs',  4, 1)

    print("Undgrad List:")
    reg_stud.undgrad_list.print_tree(reg_stud.undgrad_list.root)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 142
#     140 reg_stud = stud_registration()
#     141 list = None
# --> 142 reg_stud.register_student('a', 'cs', 4, 3)
#     143 reg_stud.register_student('b', 'math', 3, 4)
#     144 reg_stud.register_student('c', 'cs',3, 6)
#
# Cell In[2], line 134, in stud_registration.register_student(self, name, major, year, reg_day)
#     132     else:
#     133         priority = self.undgrad_priority(major, year, reg_day)
# --> 134         self.undgrad_list.root = self.undgrad_list.insert(self.undgrad_list.root, name, (major, year, reg_day, priority))
#     135 else:
#     136     self.waitlist[name] = [(major, year, reg_day)]
#
# Cell In[2], line 67, in AVL_Tree.insert(self, parent_node, name, values)
#      65 def insert(self, parent_node, name, values):
#      66     if parent_node is None:
# ---> 67         return Node(name, [values])
#      69     if self.compare_dict_values(self, values, parent_node):
#      70         parent_node.left = self.insert(parent_node.left, name, values)
#
# TypeError: Node.__init__() takes 2 positional arguments but 3 were given

# %%
class Node:
    def __init__(self, name, values):
        self.name = name # student's name
        self.values = values # information about year, registration day, and major

        # when inputing a node there is no child attached 
        self.left = None 
        self.right = None
        self.height = 1 # will be used to help determine rebalancing 

def compare_dict_values(values, node):
        # child_value = values[3]
        print(values)
        largest_value = node.values[0][3]  # Access values from the current node
        print(largest_value)
        # if child_value == largest_value and indx < 2:
        #     indx += 1
        #     return self.compare_dict_values(values, node, indx)  # Call recursively without 'self'

        return True if values > largest_value else False
def insert(parent_node, name, values):
    print(values)
    if parent_node is None:
        return Node(name, [values])

    if compare_dict_values(values[3], parent_node.values):
        parent_node.left = insert(parent_node.left, name, values)
    else:
        parent_node.right = insert(parent_node.right, name, values)

class stud_registration:
    def __init__(self):
        self.grad_list = {}
        self.undgrad_list = AVL_Tree()
        self.auditor_list = {}
        # self.waitlist = {}

    def audit_priority(self,reg_day): 
        level = 0 #reset the level for each function call
        level = level + (.5-(.1*(reg_day))) # level will equal 0.5 for registrations before orientation week, 0.4 for registrations on the first day, etc.
        return(level) #returns the updated dictionary
        
    def undgrad_priority(self, major, year, reg_day):     
        level = 0
        if major == 'cs' or major == 'math':
            level = level+10 # adds 10 to the level for cs or math majors,
            
        level = level + year # adds 1,2,3, or 4 to the level based on the year. 
        level = level +(.5-(.1*(reg_day))) #+0.5 for students registered before the orientation week, same as for auditors.

        return(level) #return the updated dictionary

    def register_student(self, name,major, year, reg_day):
        if int(reg_day) < 6:
            if int(year) > 4:
                self.grad_list[name] = [(major, year, reg_day)]
            elif int(year) == 0:
                priority = self.audit_priority(reg_day)
                self.auditor_list[name] = [(major, year, reg_day)]
            else:
                priority = self.undgrad_priority(major, year, reg_day)

                if self.undgrad_list == None:
                    self.undgrad_list= Node(name,[(major, year, reg_day)])
                else:
                    priority = self.undgrad_priority(major, year, reg_day)
                    self.undgrad_list.root = insert(self.undgrad_list, name, (major, year, reg_day, priority))
        # else:
        #             self.waitlist = {}

if __name__ == "__main__":
    reg_stud = stud_registration()
    list = None
    reg_stud.register_student('a', 'cs', 4, 3)
    reg_stud.register_student('b', 'math', 3, 4)
    reg_stud.register_student('c', 'cs',3, 6)
    reg_stud.register_student('d', 'cs', 4, 2)
    reg_stud.register_student('e', 'art',  0, 1)
    reg_stud.register_student('f', 'cs',  4, 1)
# Out:
# ('cs', 4, 3, 14.2)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 74
#      72 reg_stud = stud_registration()
#      73 list = None
# ---> 74 reg_stud.register_student('a', 'cs', 4, 3)
#      75 reg_stud.register_student('b', 'math', 3, 4)
#      76 reg_stud.register_student('c', 'cs',3, 6)
#
# Cell In[16], line 67, in stud_registration.register_student(self, name, major, year, reg_day)
#      65 else:
#      66     priority = self.undgrad_priority(major, year, reg_day)
# ---> 67     self.undgrad_list.root = insert(self.undgrad_list, name, (major, year, reg_day, priority))
#
# Cell In[16], line 26, in insert(parent_node, name, values)
#      23 if parent_node is None:
#      24     return Node(name, [values])
# ---> 26 if compare_dict_values(values[3], parent_node.values):
#      27     parent_node.left = insert(parent_node.left, name, values)
#      28 else:
#
# AttributeError: 'AVL_Tree' object has no attribute 'values'

# %%
# class Node deals with the information about the relation and information that each node contains 
class Node:
    def __init__(self, name, major, year, reg_day, priority):
        self.name = name # student's name
        self.major = major # major of the student
        self.year = year # the year the student is in
        self.reg_day = reg_day # day of registration 
        self.priority = priority # used in comparsion based analysis for developing priority 

        # when inputing a node there is no child attached 
        self.left = None 
        self.right = None
        self.height = 1 # will be used to help determine rebalancing 

# class AVL_Tree contains information about the structure of AVL_Tree and how to maintain it
# such as the rotation, insertion, and deletion form the tree
class AVL_Tree:
    def __init__(self):
        self.root = None # initially, the tree is empty because we have not put in any new students 

    # determines the tree height of each subtree, helps to determine if the subtree needs to be rotated and in which direction
    def tree_height(self, node):
        if node is None:
            return 0
        left_height = self.tree_height(node.left) # getting the height of the left subtree
        right_height = self.tree_height(node.right) # getting the height of the right subtree
        return max(left_height, right_height) + 1 # return the subtree which has the largest depth (adding 1 since we start our count at 0)
    
    def left_left_rotation(self, node):
        new_parent = node.right # setting the right child as the pivot/new parent
        temp_var = new_parent.left # temparary variable that will be reattached when tree has been rotated
        new_parent.left = node # setting parent node as left child
        node.right = temp_var # since the node is going to be smaller than the temp var, it is going to be placed as right child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right)) + 1 
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right)) + 1

        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent
    
    def right_right_rotation(self, node):
        new_parent = node.left # setting the left child as the pivot/new parent
        temp_var = new_parent.right # temparary variable that will be reattached when tree has been rotated
        new_parent.right = node # setting parent node as right child
        node.left = temp_var # since the node is going to be bigger than the temp var, it is going to be placed as left child

        # since we repositioned the parent node and the right child's position, we need to update the height of each
        node.height = max(self.tree_height(node.left), self.tree_height(node.right)) + 1
        new_parent.height = max(self.tree_height(new_parent.left), self.tree_height(new_parent.right)) + 1

        # return the new_parent for recalculation to see if the tree is now balanced
        return new_parent

    def left_right_rotation(self, node):
        node.left = self.left_left_rotation(node.left)
        return self.right_right_rotation(node)

    def right_left_rotation(self, node):
        node.right = self.right_right_rotation(node.right)
        return self.left_left_rotation(node)
 
    # inserting a new student into the AVL tree
    def insert(self, parent_node, name, major, year, reg_day, priority):
        # set the student to the root node if it is going to be ther first thing in the list 
        if parent_node is None:
            # in here we care using the node class to create the root node
            return Node(name, major, year, reg_day, priority)  

        # We are inserting the following students based on their priority value
        # the new student has a lower priority value than the students already in the tree
        if priority < parent_node.priority:
            parent_node.left = self.insert(parent_node.left, name, major, year, reg_day, priority)
            
        # the new student has a higher priority value than the students already in the tree
        else:
            parent_node.right = self.insert(parent_node.right, name, major, year, reg_day, priority)

        # once we add the new node we need to update the height of our tree that will be used to determine 
        # balance of our new tree
        parent_node.height = max(self.tree_height(parent_node.left), self.tree_height(parent_node.right)) + 1
       
        # if the balance is greater than 1 or smaller than -1 (so 2 or -2) means we are no longer balanced 
        # thus we need to rotate the nodes to rebalance the tree such that it is between -1>= x =<1
        balance = self.tree_height(parent_node.left) - self.tree_height(parent_node.right)
        
        # there is a string of left child that outweighs how many right child there is in the subtree
        if balance > 1:
            if priority < parent_node.left.priority:
                return self.right_right_rotation(parent_node)
            else:
                return self.left_right_rotation(parent_node)
            
        # there is a string of right child that outweighs how many left child there is in the subtree
        if balance < -1:
            if priority > parent_node.right.priority:
                return self.left_left_rotation(parent_node)
            else:
                return self.right_left_rotation(parent_node)

        return parent_node
        
    def print_tree(self, node):
        if node:
            self.print_tree(node.right)
            print(node.name, node.major, node.year, node.reg_day, node.priority)
            self.print_tree(node.left)

class stud_registration:
    def __init__(self):
        self.grad_list = {}
        self.undgrad_list = AVL_Tree()
        self.auditor_list = AVL_Tree()
        self.waitlist = {}

    def audit_priority(self,reg_day): 
        level = 0 #reset the level for each function call
        level = level + (.5-(.1*(reg_day))) # level will equal 0.5 for registrations before orientation week, 0.4 for registrations on the first day, etc.
        return(level) #returns the updated dictionary
        
    def undgrad_priority(self, major, year, reg_day):     
        level = 0
        if major == 'cs' or major == 'math':
            level = level+10 # adds 10 to the level for cs or math majors,
            
        level = level + year # adds 1,2,3, or 4 to the level based on the year. 
        level = level +(.5-(.1*(reg_day))) #+0.5 for students registered before the orientation week, same as for auditors.

        return(level) #return the updated dictionary

    def register_student(self, name, major, year, reg_day):
        if int(reg_day) < 6:
            if int(year) > 4:
                self.grad_list[name] = [(major, year, reg_day)]
            elif int(year) == 0:
                priority = self.audit_priority(reg_day)
                if self.auditor_list.root is None:
                    self.auditor_list.root = self.auditor_list.insert(self.auditor_list.root, name, major, year, reg_day, priority)
                else:
                    priority = self.undgrad_priority(major, year, reg_day)
                    self.auditor_list.root = self.auditor_list.insert(self.auditor_list.root, name, major, year, reg_day, priority)
            else:
                priority = self.undgrad_priority(major, year, reg_day)
                if self.undgrad_list.root is None:
                    self.undgrad_list.root = self.undgrad_list.insert(self.undgrad_list.root, name, major, year, reg_day, priority)
                else:
                    priority = self.undgrad_priority(major, year, reg_day)
                    self.undgrad_list.root = self.undgrad_list.insert(self.undgrad_list.root, name, major, year, reg_day, priority)
        else:
            self.waitlist = {}

if __name__ == "__main__":
    reg_stud = stud_registration()

    # Insert students
    reg_stud.register_student('Alice', 'cs', 3, 3)
    reg_stud.register_student('Bob', 'math', 2, 4)
    reg_stud.register_student('Charlie', 'art', 2, 1)
    reg_stud.register_student('David', 'cs', 3, 2)
    reg_stud.register_student('Eve', 'art',  5, 1)
    reg_stud.register_student('Frank', 'cs',  0, 1)

    print("Undgrad List:")
    reg_stud.undgrad_list.print_tree(reg_stud.undgrad_list.root)

    print("Auditor List:")
    reg_stud.auditor_list.print_tree(reg_stud.auditor_list.root)
# Out:
# Undgrad List:
# David cs 3 2 13.3
# Alice cs 3 3 13.2
# Bob math 2 4 12.1
# Charlie art 2 1 2.4
# Auditor List:
# Frank cs 0 1 0.4

# %%
reg_stud = stud_registration()

# Insert students
reg_stud.register_student('Alice', 'cs', 3, 3)
reg_stud.register_student('Bob', 'math', 2, 4)
reg_stud.register_student('Charlie', 'cs', 2, 6)
reg_stud.register_student('David', 'cs', 3, 2)
reg_stud.register_student('Eve', 'art',  0, 1)
reg_stud.register_student('Frank', 'cs',  4, 1)

# Print the tree to check its structure
print("Undgrad List:")
reg_stud.undgrad_list.print_tree(reg_stud.undgrad_list.root)
# Out:
# Undgrad List:
# Bob math 2 4
# Alice cs 3 3
# David cs 3 2
# Frank cs 4 1

# %%
reg_list = [('m', 0, 5, -2), ('d', 0, 6, -2), ('a', 1, 4, -2), ('j', 1, 2, -1), ('k', 1, 1, -5)]
head = heap_sort(reg_list)

df = pd.DataFrame(head, columns=['Name', 'Major', 'Grade', 'Registration Day'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 reg_list = [('m', 0, 5, -2), ('d', 0, 6, -2), ('a', 1, 4, -2), ('j', 1, 2, -1), ('k', 1, 1, -5)]
# ----> 2 head = heap_sort(reg_list)
#       4 df = pd.DataFrame(head, columns=['Name', 'Major', 'Grade', 'Registration Day'])
#       5 print(df)
#
# NameError: name 'heap_sort' is not defined
